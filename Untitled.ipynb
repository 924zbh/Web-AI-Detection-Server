# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

img= cv2.imread("1.jpeg")

# %%
img
# Out:
# array([[[ 54,  58, 114],
#         [ 54,  58, 114],
#         [ 64,  67, 124],
#         ...,
#         [ 37,  34,  55],
#         [ 37,  34,  55],
#         [ 37,  34,  55]],
#
#        [[ 50,  53, 110],
#         [ 64,  67, 124],
#         [ 54,  58, 114],
#         ...,
#         [ 37,  34,  55],
#         [ 37,  34,  55],
#         [ 37,  34,  55]],
#
#        [[ 50,  53, 110],
#         [ 64,  67, 124],
#         [ 54,  58, 114],
#         ...,
#         [ 37,  34,  55],
#         [ 37,  34,  55],
#         [ 37,  34,  55]],
#
#        ...,
#
#        [[ 52,  64, 123],
#         [ 49,  60, 117],
#         [ 47,  55, 111],
#         ...,
#         [ 57,  72, 129],
#         [ 59,  74, 131],
#         [ 61,  74, 131]],
#
#        [[ 53,  65, 125],
#         [ 51,  60, 120],
#         [ 48,  56, 114],
#         ...,
#         [ 59,  74, 131],
#         [ 59,  74, 131],
#         [ 61,  74, 131]],
#
#        [[ 53,  65, 125],
#         [ 51,  60, 120],
#         [ 48,  56, 114],
# ...

# %%
cv2.imshow("image",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
